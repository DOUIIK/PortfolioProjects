# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10674
# 1    1027     Ethereum    ETH      ethereum              8078
# 2     825  Tether USDt   USDT        tether             69128
# 3    1839          BNB    BNB           bnb              1903
# 4    5426       Solana    SOL        solana               563
# 5      52          XRP    XRP           xrp              1184
# 6    3408         USDC   USDC      usd-coin             15664
# 7    2010      Cardano    ADA       cardano              1008
# 8    5805    Avalanche   AVAX     avalanche               609
# 9      74     Dogecoin   DOGE      dogecoin               860
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # for dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

    
    #for creating a csv file :
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    #if not os.path.isfile(r'C:\Users\Douik\Desktop\data analyst project\API.csv'):
        #df.to_csv(r'C:\Users\Douik\Desktop\data analyst project\API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\Douik\Desktop\data analyst project\API.csv', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_14228\844866381.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# API Runner completed
# D:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# ...

# %%
df99 = pd.read_csv(r'C:\Users\Douik\Desktop\data analyst project\API.csv')
df99
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             10666
# 1            1   1027     Ethereum    ETH      ethereum              8069
# 2            2    825  Tether USDt   USDT        tether             68868
# 3            3   1839          BNB    BNB           bnb              1889
# 4            4     52          XRP    XRP           xrp              1181
# 5            5   5426       Solana    SOL        solana               563
# 6            6   3408         USDC   USDC      usd-coin             15605
# 7            7   2010      Cardano    ADA       cardano              1008
# 8            8   5805    Avalanche   AVAX     avalanche               605
# 9            9     74     Dogecoin   DOGE      dogecoin               860
# 10          10   1958         TRON    TRX          tron               893
# 11          11   6636     Polkadot    DOT  polkadot-new               648
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10674
# 1    1027     Ethereum    ETH      ethereum              8078
# 2     825  Tether USDt   USDT        tether             69128
# 3    1839          BNB    BNB           bnb              1903
# 4    5426       Solana    SOL        solana               563
# 5      52          XRP    XRP           xrp              1184
# 6    3408         USDC   USDC      usd-coin             15664
# 7    2010      Cardano    ADA       cardano              1008
# 8    5805    Avalanche   AVAX     avalanche               609
# 9      74     Dogecoin   DOGE      dogecoin               860
# 10   6636     Polkadot    DOT  polkadot-new               649
# 11   1958         TRON    TRX          tron               893
# 12   1975    Chainlink   LINK     chainlink              1523
# 13  11419      Toncoin    TON       toncoin               179
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -1.06691                      -0.61618
# Ethereum                        -1.12691                      -0.87588
# Tether USDt                      0.00343                       0.00320
# BNB                             -0.28130                       5.65922
# Solana                          -0.91604                       9.65180
# XRP                             -0.59904                      -0.91768
# USDC                            -0.00733                      -0.02356
# Cardano                         -1.61996                      -0.61847
# Avalanche                       -1.45184                       3.71284
# Dogecoin                        -1.14620                      -0.90973
# Polkadot                        -0.14286                       7.96984
# TRON                            -0.35608                       1.05456
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -1.06691
#              quote.USD.percent_change_24h    -0.61618
#              quote.USD.percent_change_7d      2.68485
#              quote.USD.percent_change_30d    19.48335
#              quote.USD.percent_change_60d    46.38582
#              quote.USD.percent_change_90d    64.20116
# Ethereum     quote.USD.percent_change_1h     -1.12691
#              quote.USD.percent_change_24h    -0.87588
#              quote.USD.percent_change_7d     -2.46868
#              quote.USD.percent_change_30d    11.98524
#              quote.USD.percent_change_60d    36.76411
#              quote.USD.percent_change_90d    39.65972
# Tether USDt  quote.USD.percent_change_1h      0.00343
#              quote.USD.percent_change_24h     0.00320
#              quote.USD.percent_change_7d     -0.01372
#              quote.USD.percent_change_30d    -0.00346
#              quote.USD.percent_change_60d    -0.03036
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -1.06691
#             quote.USD.percent_change_24h  -0.61618
#             quote.USD.percent_change_7d    2.68485
#             quote.USD.percent_change_30d  19.48335
#             quote.USD.percent_change_60d  46.38582
#             quote.USD.percent_change_90d  64.20116
# Ethereum    quote.USD.percent_change_1h   -1.12691
#             quote.USD.percent_change_24h  -0.87588
#             quote.USD.percent_change_7d   -2.46868
#             quote.USD.percent_change_30d  11.98524
#             quote.USD.percent_change_60d  36.76411
#             quote.USD.percent_change_90d  39.65972
# Tether USDt quote.USD.percent_change_1h    0.00343
#             quote.USD.percent_change_24h   0.00320
#             quote.USD.percent_change_7d   -0.01372
#             quote.USD.percent_change_30d  -0.00346
#             quote.USD.percent_change_60d  -0.03036
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -1.06691
# 1       Bitcoin  quote.USD.percent_change_24h  -0.61618
# 2       Bitcoin   quote.USD.percent_change_7d   2.68485
# 3       Bitcoin  quote.USD.percent_change_30d  19.48335
# 4       Bitcoin  quote.USD.percent_change_60d  46.38582
# 5       Bitcoin  quote.USD.percent_change_90d  64.20116
# 6      Ethereum   quote.USD.percent_change_1h  -1.12691
# 7      Ethereum  quote.USD.percent_change_24h  -0.87588
# 8      Ethereum   quote.USD.percent_change_7d  -2.46868
# 9      Ethereum  quote.USD.percent_change_30d  11.98524
# 10     Ethereum  quote.USD.percent_change_60d  36.76411
# 11     Ethereum  quote.USD.percent_change_90d  39.65972
# 12  Tether USDt   quote.USD.percent_change_1h   0.00343
# 13  Tether USDt  quote.USD.percent_change_24h   0.00320
# 14  Tether USDt   quote.USD.percent_change_7d  -0.01372
# 15  Tether USDt  quote.USD.percent_change_30d  -0.00346
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -1.06691
# 1       Bitcoin  quote.USD.percent_change_24h  -0.61618
# 2       Bitcoin   quote.USD.percent_change_7d   2.68485
# 3       Bitcoin  quote.USD.percent_change_30d  19.48335
# 4       Bitcoin  quote.USD.percent_change_60d  46.38582
# 5       Bitcoin  quote.USD.percent_change_90d  64.20116
# 6      Ethereum   quote.USD.percent_change_1h  -1.12691
# 7      Ethereum  quote.USD.percent_change_24h  -0.87588
# 8      Ethereum   quote.USD.percent_change_7d  -2.46868
# 9      Ethereum  quote.USD.percent_change_30d  11.98524
# 10     Ethereum  quote.USD.percent_change_60d  36.76411
# 11     Ethereum  quote.USD.percent_change_90d  39.65972
# 12  Tether USDt   quote.USD.percent_change_1h   0.00343
# 13  Tether USDt  quote.USD.percent_change_24h   0.00320
# 14  Tether USDt   quote.USD.percent_change_7d  -0.01372
# 15  Tether USDt  quote.USD.percent_change_30d  -0.00346
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#            name               percent_change    values
# 0       Bitcoin  quote.USD.percent_change_1h  -1.06691
# 1       Bitcoin                          24h  -0.61618
# 2       Bitcoin                           7d   2.68485
# 3       Bitcoin                          30d  19.48335
# 4       Bitcoin                          60d  46.38582
# 5       Bitcoin                          90d  64.20116
# 6      Ethereum  quote.USD.percent_change_1h  -1.12691
# 7      Ethereum                          24h  -0.87588
# 8      Ethereum                           7d  -2.46868
# 9      Ethereum                          30d  11.98524
# 10     Ethereum                          60d  36.76411
# 11     Ethereum                          90d  39.65972
# 12  Tether USDt  quote.USD.percent_change_1h   0.00343
# 13  Tether USDt                          24h   0.00320
# 14  Tether USDt                           7d  -0.01372
# 15  Tether USDt                          30d  -0.00346
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      43695.64958 2023-12-21 14:50:59.490833
# 0  Bitcoin      43743.94148                        NaT
# 0  Bitcoin      43730.17704                        NaT
# 0  Bitcoin      43730.44281                        NaT

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
